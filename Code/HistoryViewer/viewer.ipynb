# %%
import os
import copy
from dataclasses import dataclass
import pickle
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 9
#       7 import numpy as np
#       8 import pandas as pd
# ----> 9 import ModelsUtils as Utils
#
# ModuleNotFoundError: No module named 'ModelsUtils'

# %%
history = None
with open('history.pkl', 'rb') as fp:
        history = pickle.load(fp)

# %%
def plot_model_history(history, title):
    loss = history['train_accum_loss']
    val_loss = history['valid_loss']
    acc = history['train_accum_accuracy']
    val_acc = history['valid_accuracy']
    
    # show best epoch with a red line ?

    epochs = range(1, len(loss) + 1)

    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 5))
    
    fig.suptitle(title)
    
    ax[0].set(title='Loss')
    ax[0].plot(epochs, loss, label='Training')
    ax[0].plot(epochs, val_loss, label='Validation')
    ax[0].legend(loc="upper right")
    
    ax[1].set(title='accuracy')
    ax[1].plot(epochs, acc, label='Training')
    ax[1].plot(epochs, val_acc, label='Validation')
    ax[1].legend(loc="lower right")
    
    plt.close(fig)
    return fig

# %%
history
# Out:
# {'train_accum_loss': [0.6969012494694194,
#   0.6898536682969593,
#   0.6530905850704534],
#  'train_accum_accuracy': [0.517277856135402,
#   0.546015514809591,
#   0.6071932299012694],
#  'valid_loss': [0.6969304224358329, 0.6986168964376932, 0.7073858157743381],
#  'valid_accuracy': [0.5023771790808241,
#   0.5309033280507132,
#   0.5309033280507132],
#  'best_epoch': 1,
#  'best_loss': 0.6969304224358329,
#  'best_acc': 0.5023771790808241}

# %%
plot_model_history(history, "Trainning History")
